# %%
import pandas as pd
data={
    "Name":["Amit","Rohit","Sneha","Priya","Karan"],
    "Age":[20,21,19,None,20],
    "Marks":[78,85,None,67,88]
}
df=pd.DataFrame(data)
df
# Out:
#     Name   Age  Marks
# 0   Amit  20.0   78.0
# 1  Rohit  21.0   85.0
# 2  Sneha  19.0    NaN
# 3  Priya   NaN   67.0
# 4  Karan  20.0   88.0

# %%
df.loc[:,["Age"]]
# Out:
#     Age
# 0  20.0
# 1  21.0
# 2  19.0
# 3   NaN
# 4  20.0

# %%
df.loc[:,["Name","Marks"]]
# Out:
#     Name  Marks
# 0   Amit   78.0
# 1  Rohit   85.0
# 2  Sneha    NaN
# 3  Priya   67.0
# 4  Karan   88.0

# %%
df.head(3)
# Out:
#     Name   Age  Marks
# 0   Amit  20.0   78.0
# 1  Rohit  21.0   85.0
# 2  Sneha  19.0    NaN

# %%
df.iloc[0,2]
# Out:
# np.float64(78.0)

# %%
df.loc[0:2,["Name","Marks"]]
# Out:
#     Name  Marks
# 0   Amit   78.0
# 1  Rohit   85.0
# 2  Sneha    NaN

# %%
df[df["Marks"]>85]
# Out:
#     Name   Age  Marks
# 4  Karan  20.0   88.0

# %%
df[df["Age"]==20]
# Out:
#     Name   Age  Marks
# 0   Amit  20.0   78.0
# 4  Karan  20.0   88.0

# %%
df[(df["Marks"]>80) & (df["Age"]<=20)]
# Out:
#     Name   Age  Marks
# 4  Karan  20.0   88.0

# %%
df[(df["Marks"]>90)|(df["Marks"]<70)]
# Out:
#     Name  Age  Marks
# 3  Priya  NaN   67.0

# %%
df.rename(columns={"Marks":"Score","Age":"Current Age"},inplace=True)

# %%
df
# Out:
#     Name  Current Age  Score
# 0   Amit         20.0   78.0
# 1  Rohit         21.0   85.0
# 2  Sneha         19.0    NaN
# 3  Priya          NaN   67.0
# 4  Karan         20.0   88.0

# %%
df.sort_values("Score",ascending=False)
# Out:
#     Name  Current Age  Score
# 4  Karan         20.0   88.0
# 1  Rohit         21.0   85.0
# 0   Amit         20.0   78.0
# 3  Priya          NaN   67.0
# 2  Sneha         19.0    NaN

# %%
df.sort_values("Current Age")
# Out:
#     Name  Current Age  Score
# 2  Sneha         19.0    NaN
# 0   Amit         20.0   78.0
# 4  Karan         20.0   88.0
# 1  Rohit         21.0   85.0
# 3  Priya          NaN   67.0

# %%
df["City"]=["Delhi","Mumbai","Delhi","Pune","Delhi"]

# %%
df["City"].value_counts()
# Out:
# City
# Delhi     3
# Mumbai    1
# Pune      1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name           0
# Current Age    1
# Score          1
# City           0
# dtype: int64

# %%
df["Current Age"]=df["Current Age"].fillna(df["Current Age"].mean())
df
# Out:
#     Name  Current Age  Score    City
# 0   Amit         20.0   78.0   Delhi
# 1  Rohit         21.0   85.0  Mumbai
# 2  Sneha         19.0    NaN   Delhi
# 3  Priya         20.0   67.0    Pune
# 4  Karan         20.0   88.0   Delhi

# %%
df["Score"]=df["Score"].fillna(df["Score"].median())
df
# Out:
#     Name  Current Age  Score    City
# 0   Amit         20.0   78.0   Delhi
# 1  Rohit         21.0   85.0  Mumbai
# 2  Sneha         19.0   81.5   Delhi
# 3  Priya         20.0   67.0    Pune
# 4  Karan         20.0   88.0   Delhi

# %%
df.isna().sum()
# Out:
# Name           0
# Current Age    0
# Score          0
# City           0
# dtype: int64
