# %% [markdown]
# ***DAY 1***

# %%
import pandas as pd
data={
    "Name":["Amit","Rohit","Sneha","Priya","Karan"],
    "Age":[20,None,19,22,20],
    "Marks":[78,85,None,67,88]
}
df=pd.DataFrame(data)
df
# Out:
#     Name   Age  Marks
# 0   Amit  20.0   78.0
# 1  Rohit   NaN   85.0
# 2  Sneha  19.0    NaN
# 3  Priya  22.0   67.0
# 4  Karan  20.0   88.0

# %% [markdown]
# # To know the shape

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# # To Know the column

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %% [markdown]
# # To know all info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     4 non-null      float64
#  2   Marks   4 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 252.0 bytes

# %% [markdown]
# # To Describe the data

# %%
df.describe()
# Out:
#              Age      Marks
# count   4.000000   4.000000
# mean   20.250000  79.500000
# std     1.258306   9.327379
# min    19.000000  67.000000
# 25%    19.750000  75.250000
# 50%    20.000000  81.500000
# 75%    20.500000  85.750000
# max    22.000000  88.000000

# %% [markdown]
# # 1.Select one column

# %%
df["Name"]
# Out:
# 0     Amit
# 1    Rohit
# 2    Sneha
# 3    Priya
# 4    Karan
# Name: Name, dtype: str

# %% [markdown]
# # 2. Select Multiple columns

# %%
df[["Name","Marks","Age"]]
# Out:
#     Name  Marks   Age
# 0   Amit   78.0  20.0
# 1  Rohit   85.0   NaN
# 2  Sneha    NaN  19.0
# 3  Priya   67.0  22.0
# 4  Karan   88.0  20.0

# %% [markdown]
# # 3. Selecting rows with iloc[]

# %%
# First Row
df.iloc[0]
# Out:
# Name     Amit
# Age      20.0
# Marks    78.0
# Name: 0, dtype: object

# %% [markdown]
# # 4. Selecting Specific column and row

# %%
df.iloc[0,2]
# Out:
# np.float64(78.0)

# %%
df.iloc[2,0]
# Out:
# 'Sneha'

# %% [markdown]
# # 5. Select rows and columns together

# %%
df.iloc[0:3,0:2]
# Out:
#     Name   Age
# 0   Amit  20.0
# 1  Rohit   NaN
# 2  Sneha  19.0

# %% [markdown]
# # 6. Usinf loc[]

# %%
df.loc[:,["Name","Marks"]]
# Out:
#     Name  Marks
# 0   Amit   78.0
# 1  Rohit   85.0
# 2  Sneha    NaN
# 3  Priya   67.0
# 4  Karan   88.0

# %%
df.loc[0]
# Out:
# Name     Amit
# Age      20.0
# Marks    78.0
# Name: 0, dtype: object

# %% [markdown]
# # Filtering the data

# %%
df["Marks"]>80
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Marks, dtype: bool

# %%
df[df["Marks"]>80]
# Out:
#     Name   Age  Marks
# 1  Rohit   NaN   85.0
# 4  Karan  20.0   88.0

# %%
df[df["Marks"]<80]
# Out:
#     Name   Age  Marks
# 0   Amit  20.0   78.0
# 3  Priya  22.0   67.0

# %%
df[df["Marks"]==85]
# Out:
#     Name  Age  Marks
# 1  Rohit  NaN   85.0

# %% [markdown]
# # Multiple Condition

# %%
df[(df["Marks"]>80) | (df["Marks"]<22)]
# Out:
#     Name   Age  Marks
# 1  Rohit   NaN   85.0
# 4  Karan  20.0   88.0

# %% [markdown]
# # To Add a new column

# %%
df["City"]=["Delhi","Mumbai","Delhi","Pune","Delhi"]
df
# Out:
#     Name   Age  Marks    City
# 0   Amit  20.0   78.0   Delhi
# 1  Rohit   NaN   85.0  Mumbai
# 2  Sneha  19.0    NaN   Delhi
# 3  Priya  22.0   67.0    Pune
# 4  Karan  20.0   88.0   Delhi

# %% [markdown]
# # Create a column using the calculation

# %%
df["Result"]=df["Marks"]>=40
df
# Out:
#     Name   Age  Marks    City  Result
# 0   Amit  20.0   78.0   Delhi    True
# 1  Rohit   NaN   85.0  Mumbai    True
# 2  Sneha  19.0    NaN   Delhi   False
# 3  Priya  22.0   67.0    Pune    True
# 4  Karan  20.0   88.0   Delhi    True

# %% [markdown]
# # Rename the column

# %%
df.rename(columns={"Marks":"Score"},inplace=True)
df
# Out:
#     Name   Age  Score    City  Result
# 0   Amit  20.0   78.0   Delhi    True
# 1  Rohit   NaN   85.0  Mumbai    True
# 2  Sneha  19.0    NaN   Delhi   False
# 3  Priya  22.0   67.0    Pune    True
# 4  Karan  20.0   88.0   Delhi    True

# %% [markdown]
# # To Delete the column

# %%
df.drop("City",axis=1,inplace=True)  #axis=1 is column,axis=0 is for row

# %%
df
# Out:
#     Name   Age  Score  Result
# 0   Amit  20.0   78.0    True
# 1  Rohit   NaN   85.0    True
# 2  Sneha  19.0    NaN   False
# 3  Priya  22.0   67.0    True
# 4  Karan  20.0   88.0    True

# %% [markdown]
# # To Sort The Values

# %%
df.sort_values("Score")
# Out:
#     Name   Age  Score  Result
# 3  Priya  22.0   67.0    True
# 0   Amit  20.0   78.0    True
# 1  Rohit   NaN   85.0    True
# 4  Karan  20.0   88.0    True
# 2  Sneha  19.0    NaN   False

# %% [markdown]
# # In Descending Order

# %%
df.sort_values("Score",ascending=False)
# Out:
#     Name   Age  Score  Result
# 4  Karan  20.0   88.0    True
# 1  Rohit   NaN   85.0    True
# 0   Amit  20.0   78.0    True
# 3  Priya  22.0   67.0    True
# 2  Sneha  19.0    NaN   False

# %% [markdown]
# # Sort By multiple columns

# %%
df.sort_values(["Age","Score"])
# Out:
#     Name   Age  Score  Result
# 2  Sneha  19.0    NaN   False
# 0   Amit  20.0   78.0    True
# 4  Karan  20.0   88.0    True
# 3  Priya  22.0   67.0    True
# 1  Rohit   NaN   85.0    True

# %% [markdown]
# # **I am adding city column**

# %%
df["City"]=["Delhi","Mumbai","Delhi","Pune","Delhi"]

# %%
df
# Out:
#     Name   Age  Score  Result    City
# 0   Amit  20.0   78.0    True   Delhi
# 1  Rohit   NaN   85.0    True  Mumbai
# 2  Sneha  19.0    NaN   False   Delhi
# 3  Priya  22.0   67.0    True    Pune
# 4  Karan  20.0   88.0    True   Delhi

# %% [markdown]
# # This function tells how many time the value is occuured

# %%
df["City"].value_counts()
# Out:
# City
# Delhi     3
# Mumbai    1
# Pune      1
# Name: count, dtype: int64

# %% [markdown]
# # To Find the missing value

# %%
df.isnull()
# Out:
#     Name    Age  Score  Result   City
# 0  False  False  False   False  False
# 1  False   True  False   False  False
# 2  False  False   True   False  False
# 3  False  False  False   False  False
# 4  False  False  False   False  False

# %% [markdown]
# # To Count the missing value

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Score     1
# Result    0
# City      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Name      0
# Age       1
# Score     1
# Result    0
# City      0
# dtype: int64

# %% [markdown]
# # To drop missing values

# %%
# df.dropna()

# %% [markdown]
# # To Fill The Missing value

# %%
# df["Age"]=df["Age"].fillna(20)

# %%
# df["Score"]=df["Score"].fillna(90)
df
# Out:
#     Name   Age  Score  Result    City
# 0   Amit  20.0   78.0    True   Delhi
# 1  Rohit   NaN   85.0    True  Mumbai
# 2  Sneha  19.0    NaN   False   Delhi
# 3  Priya  22.0   67.0    True    Pune
# 4  Karan  20.0   88.0    True   Delhi

# %% [markdown]
# # Filling the missing value by "mean"

# %%
# df["Age"]=df["Age"].fillna(df["Age"].mean())

df
# Out:
#     Name   Age  Score  Result    City
# 0   Amit  20.0   78.0    True   Delhi
# 1  Rohit   NaN   85.0    True  Mumbai
# 2  Sneha  19.0    NaN   False   Delhi
# 3  Priya  22.0   67.0    True    Pune
# 4  Karan  20.0   88.0    True   Delhi

# %%
# df["Score"]=df["Score"].fillna(df["Score"].mean())
df
# Out:
#     Name   Age  Score  Result    City
# 0   Amit  20.0   78.0    True   Delhi
# 1  Rohit   NaN   85.0    True  Mumbai
# 2  Sneha  19.0    NaN   False   Delhi
# 3  Priya  22.0   67.0    True    Pune
# 4  Karan  20.0   88.0    True   Delhi

# %% [markdown]
# # Filling the missing value by "Median"

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())
df["Score"]=df["Score"].fillna(df["Score"].median())
df
# Out:
#     Name   Age  Score  Result    City
# 0   Amit  20.0   78.0    True   Delhi
# 1  Rohit  20.0   85.0    True  Mumbai
# 2  Sneha  19.0   81.5   False   Delhi
# 3  Priya  22.0   67.0    True    Pune
# 4  Karan  20.0   88.0    True   Delhi
